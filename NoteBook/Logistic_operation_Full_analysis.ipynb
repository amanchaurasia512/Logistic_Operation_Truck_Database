# %% [markdown]
# # End-to-End Logistics Analytics Project — Overview
#
# ## Purpose of the Project
#
# This project is an end-to-end logistics analytics solution designed to analyze operational logistics data and convert it into actionable business insights.
#
# The objective is to support decision-making across logistics operations by evaluating efficiency, cost, risk, and performance at multiple levels such as drivers, vehicles, routes, and customers.
#
# This project treats logistics analytics as a **business decision support system**, not just a technical data exercise.
#
# ---
#
# ## Key Business Questions Addressed
#
# The project is designed to answer the following high-level business questions:
#
# - Which drivers and vehicles are performing efficiently?
# - Which routes generate profit versus operational loss?
# - Where are fuel and maintenance costs leaking?
# - Which customers are valuable, low-margin, or risky?
# - Where do safety risks originate and how do they evolve?
# - How do seasonal patterns affect demand, cost, and risk?
#
# ---
#
# ## Scope of Analysis
#
# The project covers the complete logistics lifecycle, including:
#
# - Driver performance
# - Fleet (truck) utilization
# - Route profitability
# - Fuel efficiency
# - Maintenance behavior
# - Customer profitability and reliability
# - Safety incidents and risk
# - Seasonal trends and patterns
#
# All analytical use cases are fully implemented using Python and Jupyter Notebook.
#
# ---
#
# ## Analytical Philosophy
#
# The project follows these core principles:
#
# - **Use-case-driven analysis** rather than exploratory metrics
# - **Business-first thinking** over technical complexity
# - **Consistency across entities** (drivers, trucks, routes, customers)
# - **Actionable insights** instead of descriptive statistics
#
# Each analysis is designed to lead to a business decision or operational insight.
#
# ---
#
# ## Project Status
#
# - All calculations, KPIs, and visualizations are completed
# - No further analysis or metric development is required
# - Current focus is documentation, validation, and presentation
#
# This document provides a high-level understanding of the project before diving into detailed analysis.

# %% [markdown]
# # End-to-End Logistics Analytics Project — Structure & Analysis Flow
#
# ## Table of Contents
#
# 1. Project Foundation & Methodology
# 2. Data Understanding & Preparation
# 3. Driver Performance Analysis
# 4. Route Profitability Analysis
# 5. Fleet Utilization Analysis
# 6. Fuel Efficiency Analysis
# 7. Maintenance Analysis
# 8. Customer Analysis
# 9. Safety Metrics Analysis
# 10. Seasonal Pattern Analysis
# 11. Cross-Use-Case Integration
# 12. Business Impact & Insights
#
# ---
#
# ## 1. Project Foundation & Methodology
#
# This section establishes the analytical foundation of the project by defining:
# - Business objectives
# - Data scope and assumptions
# - KPI definitions
# - Analytical approach
#
# This section ensures all subsequent analysis is aligned with the same logic and assumptions.
#
# ---
#
# ## 2. Data Understanding & Preparation
#
# This section explains:
# - Dataset structure and granularity
# - Key entities (drivers, trucks, routes, customers)
# - Data cleaning and preparation logic
# - Feature derivation for analysis
#
# This step ensures data quality and analytical consistency.
#
# ---
#
# ## 3. Driver Performance Analysis
#
# ### 3. Driver Performance Analysis
#
# This section evaluates driver performance using operational efficiency, reliability,
# and revenue efficiency metrics. The analysis is designed to answer the core use case:
#
# **Driver Performance: On-time rates, MPG, revenue per mile**
#
# The following analytical components are covered in this section:
#
# #### 3.1 Driver Performance Leaderboard
# - Preparation of driver-level aggregated tables from trip data
# - Selection of key performance metrics (trips, distance, time, fuel, MPG, fuel intensity)
# - Normalization of metrics using Min–Max Scaling
# - Weighted scoring to compute a composite driver performance score
# - Ranking of drivers into best and worst performers
#
# #### 3.2 Driver On-Time Performance Analysis
# - Calculation of average on-time delivery rate per driver
# - Identification of top and bottom drivers based on on-time performance
# - Comparison of reliability across drivers
#
# #### 3.3 Driver Revenue Efficiency
# - Use of pre-calculated revenue data
# - Calculation of revenue per mile to normalize revenue by distance traveled
# - Identification of drivers with high and low revenue efficiency
#
# #### 3.4 Driver Performance Visualization
# - Best vs worst driver leaderboard visualization
# - Best vs worst on-time performance visualization
# - Best vs worst revenue per mile visualization
#
# Each analysis component is kept independent to avoid metric distortion and to ensure
# clear interpretation of driver productivity, reliability, and efficiency.
#
# ---
#
#
# ---
#
# ### 4. Route Profitability Analysis
#
# This section evaluates route-level financial performance by comparing revenue,
# pricing structure, and estimated operating costs to identify profitable,
# underpriced, and risk-prone lanes.
#
# The following analytical components are covered:
#
# #### 4.1 Route-Level Revenue Aggregation
# - Aggregation of load-level data at route and year granularity
# - Creation of a route revenue master table (one row per route per year)
# - Integration of route master attributes (distance, rates, transit time)
#
# #### 4.2 Normalized Revenue Metrics
# - Calculation of total route revenue
# - Revenue per mile for fair comparison across route lengths
# - Revenue per day to account for transit duration differences
#
# #### 4.3 Pricing Benchmark & Variance Analysis
# - Expected revenue estimation using distance and base rate
# - Price variance calculation to identify underpriced routes
# - Fuel surcharge dependency assessment
#
# #### 4.4 Estimated Route Cost & Profitability
# - Estimation of route-level fuel cost using fleet average MPG
# - Calculation of profit per mile and profit per day
# - Separation of revenue and estimated operating cost
#
# #### 4.5 Risk Indicators & Route Health Classification
# - Fuel loss, underpricing, surcharge dependency, and low-density flags
# - Consolidation of metrics into route health categories:
#   Strong, At Risk, and Weak
#
# #### 4.6 Final Route Profitability Tables
# - Top and bottom routes by profit per mile
# - Route cost and profitability master table
# - Route health summary and year-over-year trend tables
#
# ---
#
# ## 6. Fuel Efficiency Analysis
#
# This section analyzes fuel usage across:
# - Trips
# - Drivers
# - Trucks
# - Time
#
# The objective is to identify inefficiencies, anomalies, and cost-saving opportunities.
#
# ---
#
# ## 7. Maintenance Analysis
#
# This section examines vehicle health and maintenance behavior through:
# - Maintenance frequency
# - Cost trends
# - Usage versus breakdown relationships
#
# The analysis supports preventive maintenance and asset management decisions.
#
# ---
#
# ## 8. Customer Analysis
#
# This section evaluates customer value and reliability by analyzing:
# - Shipment volume
# - Revenue contribution
# - Cost-to-serve
# - Service performance
#
# Customers are segmented to guide prioritization and contract decisions.
#
# ---
#
# ## 9. Safety Metrics Analysis
#
# This section focuses on operational safety by analyzing:
# - Incident frequency and causes
# - Risk by driver, truck, and route
# - Time-based safety trends
#
# Insights support risk reduction and compliance initiatives.
#
# ---
#
# ## 10. Seasonal Pattern Analysis
#
# This section studies time-based patterns affecting logistics operations, including:
# - Demand fluctuations
# - Cost variation
# - Safety and delay patterns
#
# This analysis supports capacity planning and forecasting.
#
# ---
#
# ## 11. Cross-Use-Case Integration
#
# This section explains how insights across different analyses are connected:
# - Driver behavior affects fuel and safety
# - Truck usage impacts maintenance and cost
# - Routes link profitability, delays, and incidents
# - Customers connect revenue, cost, and reliability
#
# This integration ensures holistic decision-making.
#
# ---
#
# ## 12. Business Impact & Insights
#
# This final section consolidates insights across all analyses to highlight:
# - Key operational improvement areas
# - Cost optimization opportunities
# - Risk mitigation strategies
# - Strategic planning recommendations

# %% [markdown]
# ## 1. Project Foundation & Methodology
#
# ### 1.1 Business Context
#
# This project represents an end-to-end logistics analytics framework designed to evaluate and improve logistics operations using data-driven insights.
#
# The analysis focuses on core operational areas such as transportation efficiency, cost control, asset utilization, safety, and customer service.
# It is intended to support decision-making for logistics operations teams, analysts, and management by providing structured and actionable insights derived from operational data.
#
# The project treats logistics analytics as a decision-support system rather than a purely descriptive reporting exercise.
#
# ---
#
# ### 1.2 Analytical Objectives
#
# The primary objectives of this project are to:
#
# - Evaluate operational efficiency across drivers, vehicles, routes, and customers
# - Identify cost leakage related to fuel, maintenance, and inefficient utilization
# - Assess operational risk through safety and reliability metrics
# - Support optimization and planning decisions using data-backed insights
#
# All analytical use cases in the project are aligned with these objectives.
#
# ---
#
# ### 1.3 Scope of Analysis
#
# The scope of this analysis is defined as follows:
#
# - **Time Period:** Analysis is conducted over the available historical operational data
# - **Granularity Levels:**
#   - Trip level
#   - Driver level
#   - Vehicle (truck) level
#   - Route level
#   - Customer level
#   - Time-based aggregation (monthly and seasonal)
#
# The analysis includes only operational and performance-related aspects of logistics activities. Strategic, contractual, or external market factors are outside the scope of this project.
#
# ---
#
# ### 1.4 Core Entities
#
# The project is structured around the following key entities:
#
# - **Trip:** The fundamental unit of logistics activity representing a single transportation event
# - **Driver:** The human resource responsible for executing trips
# - **Vehicle (Truck):** The asset used to perform transportation operations
# - **Route:** The path or corridor along which logistics movements occur
# - **Customer:** The recipient or owner of shipments
# - **Time:** Temporal dimensions used for trend and seasonal analysis
#
# These entities are consistently referenced across all analytical use cases to ensure integration and coherence.
#
# ---
#
# ### 1.5 KPI and Metric Philosophy
#
# Metrics and KPIs in this project are designed with a business-first mindset.
#
# Key principles include:
# - Metrics are selected based on their relevance to decision-making
# - KPIs are consistently defined and reused across multiple analyses
# - Efficiency, cost, and risk metrics are prioritized over purely descriptive statistics
#
# The goal is to ensure that every metric contributes to a potential operational or strategic decision.
#
# ---
#
# ### 1.6 Analytical Approach
#
# The project follows a structured analytics lifecycle:
#
# 1. Data understanding and preparation
# 2. Definition of business-aligned metrics and KPIs
# 3. Use-case-driven analysis across logistics domains
# 4. Classification and segmentation of entities where applicable
# 5. Business interpretation of analytical outcomes
#
# This approach ensures clarity, consistency, and logical flow throughout the project.
#
# ---
#
# ### 1.7 Assumptions and Constraints
#
# To enable structured analysis, certain assumptions and constraints are acknowledged:
#
# - Cost calculations are based on available operational data and predefined cost assumptions
# - Some real-world complexities are simplified for analytical clarity
# - Data quality and completeness depend on the source dataset
#
# These assumptions are documented to maintain transparency and interpretability of results.

# %% [markdown]
# ## 2. Data Understanding & Entity Relationships

# %%
# !pip install mermaid-py
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mermaid import Mermaid

diagram = """
graph TD
    Trip[Trip -Central_Entity]

    Driver[Driver]
    Truck[Truck]
    Route[Route]
    Customer[Customer]


    Fuel[Fuel Consumption]
    Maintenance[Maintenance Events]
    Safety[Safety Incidents]

    Driver --> Trip
    Truck --> Trip
    Route --> Trip
    Customer --> Trip
    Trailer --> Trip

    Trip --> Fuel
    Trip --> Maintenance
    Trip --> Safety
"""

Mermaid(diagram)
# Out:
# <svg id="mermaidInkSvg" width="100%" xmlns="http://www.w3.org/2000/svg" class="flowchart" style="max-width: 754.890625px;" viewBox="0 0 754.890625 278" role="graphics-document document" aria-roledescription="flowchart-v2" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaidInkSvg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaidInkSvg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaidInkSvg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaidInkSvg .error-icon{fill:#552222;}#mermaidInkSvg .error-text{fill:#552222;stroke:#552222;}#me
# ...

# %%
import pandas as pd
import numpy as np

pd.options.display.float_format = "{:.2f}".format

# %%
#load all the files

drivers_df = pd.read_csv("../Data/raw/drivers.csv")
trips_df = pd.read_csv("../Data/raw/trips.csv")
fuel_purchases_df = pd.read_csv("../Data/raw/fuel_purchases.csv")
loads_df = pd.read_csv("../Data/raw/loads.csv")
trucks_df = pd.read_csv("../Data/raw/trucks.csv")
delivery_events_df= pd.read_csv("../Data/raw/delivery_events.csv")

# %%
driver_monthly_metrics_df = pd.read_csv('../Data/raw/driver_monthly_metrics.csv')

# %%
route_df = pd.read_csv('../Data/raw/routes.csv')
trailer_df = pd.read_csv('../Data/raw/trailers.csv')
truck_utilization_metrics_df = pd.read_csv('../Data/raw/truck_utilization_metrics.csv')
facilities_df = pd.read_csv('../Data/raw/facilities.csv')
customers_df = pd.read_csv('../Data/raw/customers.csv')

# %%
trips_df.head()
# Out:
#         trip_id       load_id driver_id  truck_id trailer_id dispatch_date  \
# 0  TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167    2022-01-01
# 1  TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082    2022-01-01
# 2  TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138    2022-01-01
# 3  TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018    2022-01-01
# 4  TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054    2022-01-01
#
#    actual_distance_miles  actual_duration_hours  fuel_gallons_used  \
# 0                   1314                  26.20             183.80
# 1                    515                   8.60              93.60
# 2                   2509                  45.00             339.10
# 3                    717                  11.10             110.30
# 4                   2243                  35.00             328.90
#
#    average_mpg  idle_time_hours trip_status
# 0         7.15             3.50   Completed
# ...

# %%
def data_quality_report(df):
    total_rows = len(df)
    missing_summary = []

    print("📊 DATA QUALITY REPORT")
    print("="*60)

    # Loop through each column
    for col in df.columns:
        missing = df[col].isna().sum()
        percent = (missing / total_rows) * 100

        if missing == 0:
            status = "✅"
            line = f"{status} {col:<40}: Complete"
        else:
            status = "❌"
            line = f"{status} {col:<40}: {missing:,} missing ({percent:.1f}%)"

        print(line)
        missing_summary.append((col, missing, percent))

    # Compute overall completeness
    total_cells = df.shape[0] * df.shape[1]
    total_missing = df.isna().sum().sum()
    completeness = 100 * (1 - total_missing / total_cells)

    print(f"\n📈 Overall Data Completeness: {completeness:.1f}%")

    return pd.DataFrame(missing_summary, columns=['Column', 'Missing', 'Missing_%']).sort_values(by='Missing_%', ascending=False)

# %%
data_quality_report(trips_df)
# Out:
# 📊 DATA QUALITY REPORT
# ...
# ✅ trip_id                                 : Complete
# ✅ load_id                                 : Complete
# ❌ driver_id                               : 1,714 missing (2.0%)
# ❌ truck_id                                : 1,672 missing (2.0%)
# ❌ trailer_id                              : 1,680 missing (2.0%)
# ✅ dispatch_date                           : Complete
# ✅ actual_distance_miles                   : Complete
# ✅ actual_duration_hours                   : Complete
# ✅ fuel_gallons_used                       : Complete
# ✅ average_mpg                             : Complete
# ✅ idle_time_hours                         : Complete
# ✅ trip_status                             : Complete
#
# 📈 Overall Data Completeness: 99.5%
#                    Column  Missing  Missing_%
# 2               driver_id     1714       2.01
# 4              trailer_id     1680       1.97
# 3                truck_id     1672       1.96
# 1                 load_id        0       0.00
# ...

# %%
drivers_df.head()
# Out:
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 0  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 1  DRV00002    William     Martin  2020-10-02              NaN    DL128955006
# 2  DRV00003    Charles  Hernandez  2021-09-21              NaN    DL523076025
# 3  DRV00004    Barbara      Brown  2013-09-08              NaN    DL735540030
# 4  DRV00005       Mary   Martinez  2018-12-02              NaN    DL706011277
#
#   license_state date_of_birth   home_terminal employment_status cdl_class  \
# 0            WA    1973-11-07          Denver            Active         A
# 1            GA    1976-11-03        Columbus            Active         A
# 2            NC    1970-04-06  Salt Lake City            Active         A
# 3            WA    1995-02-06          Denver            Active         A
# 4            AZ    1960-07-15         Chicago            Active         A
#
#    years_experience
# 0                 3
# ...

# %%
trucks_df.head()
# Out:
#    truck_id  unit_number          make  model_year                 vin  \
# 0  TRK00001         3463     Peterbilt        2016  1VV205190335317039
# 1  TRK00002         6461      Kenworth        2015  1NV753749606229960
# 2  TRK00003         2335     Peterbilt        2018  1NT803101860493229
# 3  TRK00004         3317  Freightliner        2015  1VV131945381692351
# 4  TRK00005         6731  Freightliner        2016  1FT822215709701985
#
#   acquisition_date  acquisition_mileage fuel_type  tank_capacity_gallons  \
# 0       2017-04-27                18814    Diesel                    200
# 1       2018-10-04                26795    Diesel                    150
# 2       2020-09-17                11795    Diesel                    150
# 3       2017-06-17                 8875    Diesel                    200
# 4       2021-10-08                42042    Diesel                    250
#
#         status   home_terminal
# 0       Active           Omaha
# 1       Active         Seattle
# ...

# %%
print(f"drive shape :{drivers_df.shape}")
print(f"trips shape :{trips_df.shape}")
print(f"loads shape :{loads_df.shape}")
print(f"trucks shape :{trucks_df.shape}")
print(f"delivery_events shape :{delivery_events_df.shape}")
# Out:
# drive shape :(150, 12)
# trips shape :(85410, 12)
# loads shape :(85410, 12)
# trucks shape :(120, 11)
# delivery_events shape :(170820, 11)

# %% [markdown]
# ### Revenue Trend Analysis & Classification
#
# #### Purpose
#
# This analysis focuses on understanding how revenue changes over time rather than recalculating revenue itself.
#
# Since revenue is already available in the dataset, the objective is to:
# - Measure year-over-year revenue movement
# - Identify growth, stability, or decline
# - Classify entities based on revenue trends
# - Support ranking and prioritization decisions
#
# This framework is applied consistently across different entities such as routes, customers, and drivers.
#
# ---
#
# #### Revenue Usage
#
# Revenue values are taken directly from the dataset without modification.
#
# The analysis does not alter or re-estimate revenue.
# Instead, revenue is used as an input for:
# - Trend evaluation
# - Growth comparison
# - Ranking logic
#
# ---
#
# #### Year-over-Year (YoY) Growth Calculation
#
# To evaluate revenue movement over time, Year-over-Year growth is calculated using the following formula:
#
# > **YoY Growth (%) = (Current Year Revenue − Previous Year Revenue) / Previous Year Revenue × 100**
#
# This formula measures the percentage change in revenue between consecutive years.
#
# ---
#
# #### Interpretation of YoY Growth
#
# - Positive YoY growth indicates increasing revenue
# - Zero or near-zero growth indicates stable revenue
# - Negative YoY growth indicates declining revenue
#
# YoY growth allows performance comparison independent of absolute revenue size.
#
# ---
#
# #### Trend Classification Logic
#
# Based on YoY growth values, entities are classified into trend categories.
#
# A simple rule-based classification is applied:
#
# - **Growing** – YoY growth is positive
# - **Stable** – YoY growth is close to zero
# - **Declining** – YoY growth is negative
#
# This classification converts numeric growth values into intuitive business labels.
#
# ---
#
# #### Revenue Ranking Approach
#
# Entities are ranked using:
# - Total revenue contribution
# - Revenue trend classification
#
# This ensures ranking considers both:
# - Current revenue importance
# - Direction of revenue movement
#
# An entity with high revenue but declining growth is interpreted differently from one with moderate revenue and strong growth.
#
# ---
#
# #### Business Interpretation
#
# - Growing entities indicate expansion and future opportunity
# - Stable entities represent consistent performance
# - Declining entities signal potential risk or need for intervention
#
# Trend-based classification helps decision-makers focus not only on scale but also on momentum.
#
# ---
#
# #### Reusability Across the Project
#
# This YoY growth and trend classification logic is reused across multiple analytical use cases, including:
# - Route performance analysis
# - Customer revenue evaluation
# - Driver revenue contribution analysis
#
# Using a consistent approach ensures comparable and interpretable results across the project.
#
# ---
#
# #### Business Value
#
# The revenue trend framework enables:
# - Early identification of declining revenue patterns
# - Recognition of emerging growth areas
# - More informed prioritization and strategic planning
#
# By focusing on trend rather than raw values alone, the analysis supports proactive decision-making.

# %%
import pandas as pd
import numpy as np

def calc_yoy_growth_dynamic_safe(df, id_col="id", year_col="year", value_col="revenue"):
    """
    Robustly pivot (driver,year,value) -> driver rows with rev_{year}, yoy_{prev}_{cur}, cagr_{start}_{end}.
    Returns DataFrame. Raises informative errors if input is missing required cols.
    """
    # Basic checks
    if not isinstance(df, pd.DataFrame):
        raise TypeError("Input must be a pandas DataFrame.")
    for c in (id_col, year_col, value_col):
        if c not in df.columns:
            raise KeyError(f"Required column not found in dataframe: '{c}'")

    # Work on a copy
    df_in = df[[id_col, year_col, value_col]].copy()

    # Clean year column: attempt to extract integer year; if not possible, keep as-is but ensure sortable
    # We will create a helper column `__year_val` for sorting/pivot
    def to_year_val(x):
        # handle pandas Timestamps, strings like '2022-01-01', ints, or '2022'
        if pd.isna(x):
            return np.nan
        if isinstance(x, (pd.Timestamp, pd.DatetimeTZDtype, )):
            return x.year
        try:
            # numeric strings or ints
            xi = int(x)
            return xi
        except Exception:
            # try parsing as date string
            try:
                return pd.to_datetime(x, errors='coerce').year
            except Exception:
                return np.nan

    df_in["__year_val"] = df_in[year_col].apply(to_year_val)

    # If __year_val is mostly NaN (cannot parse), fallback to raw year_col values but sorted as strings
    if df_in["__year_val"].notna().sum() < len(df_in) * 0.2:
        # many unparsable, use raw values (converted to string) for grouping
        df_in["__year_key"] = df_in[year_col].astype(str)
        sort_years = sorted(df_in["__year_key"].unique())
        pivot = df_in.pivot_table(index=id_col, columns="__year_key", values=value_col, aggfunc="sum").reindex(columns=sort_years)
        # rename to rev_{label}
        pivot.columns = [f"rev_{str(c)}" for c in pivot.columns]
        pivot = pivot.reset_index()
        return pivot

    # Otherwise use integer years for pivot
    # Drop rows where __year_val is NaN (can't attribute to a year)
    df_in = df_in[~df_in["__year_val"].isna()].copy()
    df_in["__year_val"] = df_in["__year_val"].astype(int)

    # Pivot: rows=id_col, cols=year int
    pivot = df_in.pivot_table(index=id_col, columns="__year_val", values=value_col, aggfunc="sum").sort_index(axis=1)

    # Rename revenue columns to rev_{year}
    pivot = pivot.rename(columns=lambda y: f"rev_{y}")

    # Create a list of available years in ascending order
    rev_cols = [c for c in pivot.columns if str(c).startswith("rev_")]
    years = [int(c.split("_",1)[1]) for c in rev_cols]

    # Compute YoY for each consecutive pair
    for i in range(1, len(years)):
        prev_col = f"rev_{years[i-1]}"
        cur_col  = f"rev_{years[i]}"
        yoy_col  = f"yoy_{years[i-1]}_{years[i]}"

        prev = pivot[prev_col]
        cur  = pivot[cur_col]

        # safe computation: where prev is NaN or prev == 0 -> result NaN
        mask = prev.notna() & (prev != 0)
        yoy = pd.Series(np.nan, index=pivot.index, dtype=float)
        if mask.any():
            yoy.loc[mask] = ((cur.loc[mask] - prev.loc[mask]) / prev.loc[mask]) * 100.0
        pivot[yoy_col] = yoy.round(2)

    # Compute CAGR between first and last year if possible
    if len(years) >= 2:
        start_col = f"rev_{years[0]}"
        end_col   = f"rev_{years[-1]}"
        cagr_col  = f"cagr_{years[0]}_{years[-1]}"
        start_vals = pivot[start_col]
        end_vals   = pivot[end_col]
        cagr = pd.Series(np.nan, index=pivot.index, dtype=float)
        valid = start_vals.notna() & end_vals.notna() & (start_vals > 0)
        if valid.any():
            n_periods = years[-1] - years[0]
            cagr.loc[valid] = ((end_vals.loc[valid] / start_vals.loc[valid]) ** (1.0 / n_periods) - 1.0) * 100.0
        pivot[cagr_col] = cagr.round(2)

    # Reset index to make driver_id a column
    pivot = pivot.reset_index()
    return pivot

# %%
def classify_trend_safe(pivot_df, id_col="id",
                               pos_threshold=5.0, neg_threshold=-5.0, stable_abs=5.0):
    """
    Classify drivers based on available YoY columns in pivot_df.
    Returns pivot_df with new 'trend_label' column.
    """
    if id_col not in pivot_df.columns:
        raise KeyError(f"driver_col '{id_col}' not in DataFrame")

    df = pivot_df.copy()
    # identify YoY columns
    yoy_cols = [c for c in df.columns if str(c).startswith("yoy_")]
    # If none present, label and exit
    if len(yoy_cols) == 0:
        df["trend_label"] = "No Trend Data"
        return df

    # Ensure consistent order by parsing years from column names when possible
    def _parse_yoy(col):
        try:
            parts = col.split("_")
            return int(parts[1]), int(parts[2])
        except Exception:
            return (0,0)
    yoy_cols = sorted(yoy_cols, key=_parse_yoy)

    labels = []
    for _, row in df.iterrows():
        vals = []
        for c in yoy_cols:
            v = row.get(c, np.nan)
            try:
                v = float(v)
            except Exception:
                v = np.nan
            vals.append(v)
        vals_arr = np.array(vals, dtype=float)
        finite_mask = np.isfinite(vals_arr)
        n_total = finite_mask.sum()
        if n_total == 0:
            labels.append("No Trend Data")
            continue

        n_pos_strong = np.sum(vals_arr > pos_threshold)
        n_pos_any = np.sum(vals_arr > 0)
        n_neg_strong = np.sum(vals_arr < neg_threshold)
        n_near = np.sum(np.isfinite(vals_arr) & (np.abs(vals_arr) <= stable_abs))

        recent = vals_arr[-1] if np.isfinite(vals_arr[-1]) else np.nan
        prev = vals_arr[-2] if len(vals_arr) >= 2 and np.isfinite(vals_arr[-2]) else np.nan

        # Apply rules (customize thresholds above)
        if n_total == n_near:
            label = "Stable"
        elif (n_pos_strong >= (n_total / 2.0)) and (not np.isnan(recent)) and recent >= pos_threshold:
            label = "Strong Upward"
        elif (n_pos_any > n_neg_strong) and n_pos_any > 0:
            label = "Upward"
        elif (n_neg_strong >= (n_total / 2.0)) and (not np.isnan(recent)) and recent <= neg_threshold:
            label = "Declining"
        elif (not np.isnan(recent) and recent >= pos_threshold) and (not np.isnan(prev) and prev < 0):
            label = "Recovery"
        else:
            label = "Volatile"
        labels.append(label)

    df["trend_label"] = labels
    return df

# %% [markdown]
# ## 3. Driver Performance Analysis

# %% [markdown]
# ## 3.1 Driver Performance Leaderboard

# %%
driver_trip_join = trips_df.merge(drivers_df['driver_id'],on="driver_id",how='left')
driver_trip_join.head()
# Out:
#         trip_id       load_id driver_id  truck_id trailer_id dispatch_date  \
# 0  TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167    2022-01-01
# 1  TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082    2022-01-01
# 2  TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138    2022-01-01
# 3  TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018    2022-01-01
# 4  TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054    2022-01-01
#
#    actual_distance_miles  actual_duration_hours  fuel_gallons_used  \
# 0                   1314                  26.20             183.80
# 1                    515                   8.60              93.60
# 2                   2509                  45.00             339.10
# 3                    717                  11.10             110.30
# 4                   2243                  35.00             328.90
#
#    average_mpg  idle_time_hours trip_status
# 0         7.15             3.50   Completed
# ...

# %%
driver_trip_join['dispatch_date'] = pd.to_datetime(driver_trip_join['dispatch_date'],errors='coerce')
driver_trip_join['year'] = driver_trip_join['dispatch_date'].dt.year

# %%
driver_performance = driver_trip_join.groupby(['driver_id','year']).agg(
    Total_trip = ('trip_id','count'),
    Total_distance_miles = ('actual_distance_miles','sum'),
    Total_time_hours = ('actual_duration_hours','sum'),
    Total_fuel_gallons_used = ('fuel_gallons_used','sum'),
).reset_index()
driver_performance.head(10)
# Out:
#   driver_id  year  Total_trip  Total_distance_miles  Total_time_hours  \
# 0  DRV00001  2022         206                299421           5271.00
# 1  DRV00001  2023         213                315819           5538.40
# 2  DRV00001  2024         213                314996           5489.40
# 3  DRV00002  2022         216                297805           5234.80
# 4  DRV00002  2023         220                326958           5669.20
# 5  DRV00002  2024         226                318483           5597.50
# 6  DRV00003  2022         228                343957           5997.70
# 7  DRV00003  2023         249                368078           6385.90
# 8  DRV00003  2024         200                298200           5215.00
# 9  DRV00004  2022         237                355150           6159.70
#
#    Total_fuel_gallons_used
# 0                 47164.10
# 1                 48998.70
# 2                 48543.10
# 3                 46272.20
# 4                 51197.20
# 5                 49131.30
# ...

# %%
avg_fuel_price = fuel_purchases_df['price_per_gallon'].mean()
driver_performance['fuel_cost'] = driver_performance['Total_fuel_gallons_used'] * avg_fuel_price
driver_performance['Mpg'] = driver_performance['Total_distance_miles']/driver_performance['Total_fuel_gallons_used']
driver_performance['fuel_used_per_miles'] = driver_performance['fuel_cost']/driver_performance['Total_distance_miles']
driver_performance.head()
# Out:
#   driver_id  year  Total_trip  Total_distance_miles  Total_time_hours  \
# 0  DRV00001  2022         206                299421           5271.00
# 1  DRV00001  2023         213                315819           5538.40
# 2  DRV00001  2024         213                314996           5489.40
# 3  DRV00002  2022         216                297805           5234.80
# 4  DRV00002  2023         220                326958           5669.20
#
#    Total_fuel_gallons_used  fuel_cost  Mpg  fuel_used_per_miles
# 0                 47164.10  183865.38 6.35                 0.61
# 1                 48998.70  191017.42 6.45                 0.60
# 2                 48543.10  189241.30 6.49                 0.60
# 3                 46272.20  180388.38 6.44                 0.61
# 4                 51197.20  199588.09 6.39                 0.61

# %%
driver_performance.columns.to_list()
# Out:
# ['driver_id',
#  'year',
#  'Total_trip',
#  'Total_distance_miles',
#  'Total_time_hours',
#  'Total_fuel_gallons_used',
#  'fuel_cost',
#  'Mpg',
#  'fuel_used_per_miles']

# %% [markdown]
# ### Driver Performance Leaderboard
#
# #### Purpose
#
# The Driver Performance Leaderboard is designed to provide a standardized and fair comparison of drivers based on multiple operational efficiency metrics.
#
# Since drivers differ in workload, distance, and fuel usage, raw values alone are not sufficient for comparison.
# This leaderboard converts multiple performance dimensions into a single composite score that enables ranking and classification of drivers.
#
# ---
#
# #### Metrics Used
#
# The leaderboard is constructed using the following driver-level aggregated metrics:
#
# - `Total_trip` – Total number of trips completed by the driver
# - `Total_distance_miles` – Total distance covered
# - `Total_time_hours` – Total driving time
# - `Total_fuel_gallons_used` – Total fuel consumed
# - `fuel_cost` – Total fuel cost incurred
# - `Mpg` – Fuel efficiency (miles per gallon)
# - `fuel_used_per_miles` – Fuel consumption intensity
#
# Each metric captures a different aspect of driver productivity, efficiency, and cost impact.
#
# ---
#
# #### Need for Normalization
#
# The metrics used in the leaderboard are measured on different scales:
# - Trips are counts
# - Distance is in miles
# - Fuel is in gallons
# - Cost is in currency
# - Efficiency is a ratio
#
# To ensure that no single metric dominates the ranking due to scale differences, **Min–Max Scaling** is applied to all selected metrics.
#
# Min–Max Scaling transforms each metric into a standardized range between 0 and 1 while preserving relative performance differences among drivers.
#
# ---
#
# #### Weighted Scoring Approach
#
# After normalization, each metric is assigned a weight based on its relative importance to overall driver performance.
#
# The weighted approach allows the leaderboard to:
# - Emphasize efficiency over volume where required
# - Penalize excessive fuel usage
# - Balance productivity with cost and fuel efficiency
#
# The final **Driver Performance Score** is calculated as a weighted combination of all normalized metrics.
#
# This composite score represents overall driver performance in a single, interpretable value.
#
# ---
#
# #### Leaderboard Construction
#
# The leaderboard is constructed through the following steps:
#
# 1. Aggregate trip-level data at the driver-year level
# 2. Apply Min–Max Scaling to selected performance metrics
# 3. Apply predefined weights to scaled metrics
# 4. Compute a final performance score for each driver
# 5. Rank drivers based on the final score
#
# The resulting table provides a ranked view of drivers from highest to lowest performance.
#
# ---
#
# #### Interpretation of the Leaderboard
#
# - Drivers with higher scores demonstrate better overall efficiency and cost-effectiveness
# - Lower-ranked drivers may indicate:
#   - High fuel consumption
#   - Lower fuel efficiency
#   - Operational inefficiencies
#
# The leaderboard is not intended to penalize drivers but to:
# - Identify top performers
# - Highlight drivers who may benefit from training
# - Support data-driven performance management decisions
#
# ---
#
# #### Business Value
#
# The Driver Performance Leaderboard enables:
# - Objective driver evaluation
# - Fair performance comparison across varying workloads
# - Incentive and recognition programs
# - Targeted efficiency and safety interventions
#
# By combining multiple performance dimensions into a single score, the leaderboard supports transparent and actionable driver management.

# %%
from sklearn.preprocessing import MinMaxScaler

metrics_higher_better = [
    "Total_trip",
    "Total_distance_miles",
    "Mpg"
]

metrics_lower_better = [
    "Total_time_hours",
    "Total_fuel_gallons_used",
    "fuel_cost",
    "fuel_used_per_miles"
]

scaler = MinMaxScaler()

df = driver_performance.copy()

# HIGHER IS BETTER → normal min-max
for col in metrics_higher_better:
    df[f"score_{col}"] = scaler.fit_transform(df[[col]])


for col in metrics_lower_better:
    df[f"score_{col}"] = 1 - scaler.fit_transform(df[[col]])


weights = {
    "Total_trip": 0.20,
    "Total_distance_miles": 0.20,
    "Mpg": 0.25,
    "Total_time_hours": 0.10,
    "Total_fuel_gallons_used": 0.10,
    "fuel_cost": 0.10,
    "fuel_used_per_miles": 0.05
}
df["driver_score_raw"] = 0

for metric, weight in weights.items():
    df["driver_score_raw"] += df[f"score_{metric}"] * weight

df["driver_score_100"] = df["driver_score_raw"] * 100
df["rank"] = df["driver_score_100"].rank(ascending=False).astype(int)


leaderboard = df.sort_values("rank")[[
    "rank",
    "driver_id",
    "driver_score_100",
    "Total_trip",
    "Total_distance_miles",
    "Mpg",
    "Total_time_hours",
    "Total_fuel_gallons_used",
    "fuel_cost",
    "fuel_used_per_miles"
]]

display(leaderboard)
leaderboard.to_csv('../Data/processed/driver_leaderboard.csv', index=False)
# Out:
#      rank driver_id  driver_score_100  Total_trip  Total_distance_miles  Mpg  \
# 225     1  DRV00092             67.58         239                332704 6.58
# 268     2  DRV00109             64.07         221                312534 6.57
# 344     3  DRV00141             64.06         245                349701 6.55
# 146     4  DRV00059             64.02         256                370058 6.54
# 320     5  DRV00128             62.21         240                342747 6.54
# ..    ...       ...               ...         ...                   ...  ...
# 312   368  DRV00126             35.62         221                321071 6.34
# 82    369  DRV00033             35.50         228                319426 6.33
# 280   370  DRV00113             34.85         223                330156 6.34
# 0     371  DRV00001             34.63         206                299421 6.35
# 75    372  DRV00030             32.99         224                332698 6.32
#
# ...

# %%
driver_monthly_metrics_df['month'] = pd.to_datetime(driver_monthly_metrics_df['month'],errors='coerce')
driver_monthly_metrics_df['year'] = driver_monthly_metrics_df['month'].dt.year
driver_monthly_metrics_df.head()
# Out:
#   driver_id      month  trips_completed  total_miles  total_revenue  \
# 0  DRV00001 2022-01-01               26        36620       79141.59
# 1  DRV00001 2022-02-01                9        13515       27133.87
# 2  DRV00001 2022-03-01               20        30361       62399.62
# 3  DRV00001 2022-04-01               19        28127       68161.13
# 4  DRV00001 2022-05-01               14        16071       36256.82
#
#    average_mpg  total_fuel_gallons  on_time_delivery_rate  average_idle_hours  \
# 0         6.61             5574.70                   0.39                8.20
# 1         6.69             2095.10                   0.33                6.80
# 2         6.36             4792.20                   0.55                7.50
# 3         6.61             4251.40                   0.47                8.40
# 4         6.35             2573.10                   0.21                6.80
#
#    year
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022

# %% [markdown]
# #### 3.3 Driver Revenue Efficiency

# %%
drivers_revenue = driver_monthly_metrics_df.groupby(['driver_id','year']).agg(
    sum_total_revenue = ('total_revenue','sum'),
    sum_total_miles = ('total_miles','sum')
).reset_index()

drivers_revenue.head()
drivers_revenue.to_csv('../Data/processed/driver_revenue.csv', index=False)

# %%
drivers_revenue_per_miles= driver_monthly_metrics_df.groupby(['driver_id']).agg(
    sum_total_revenue = ('total_revenue','sum'),
    sum_total_miles = ('total_miles','sum')
).reset_index()

drivers_revenue_per_miles['revenue_per_miles'] = drivers_revenue_per_miles['sum_total_revenue']/drivers_revenue_per_miles['sum_total_miles']

Top_10_best_revenue_miles = drivers_revenue_per_miles.sort_values(by='revenue_per_miles',ascending=False).head(10)
Top_10_worst_revenue_miles = drivers_revenue_per_miles.sort_values(by='revenue_per_miles').head(10)

# %%
drivers_revenue_per_miles.head()
# Out:
#   driver_id  sum_total_revenue  sum_total_miles  revenue_per_miles
# 0  DRV00001         1985683.26           930236               2.13
# 1  DRV00002         2073621.50           943246               2.20
# 2  DRV00003         2146977.47          1010235               2.13
# 3  DRV00004         2119361.45           982625               2.16
# 4  DRV00005         2022357.46           923128               2.19

# %%
drivers_revenue_copy = drivers_revenue.copy()
# 2) call the robust pivot + YoY function
# Note: value_col is your revenue column name: 'sum_total_revenue'
trend_df = calc_yoy_growth_dynamic_safe(
    drivers_revenue_copy,
    id_col="driver_id",
    year_col="year",
    value_col="sum_total_revenue"
)

# 3) classify trends with default thresholds (change thresholds if needed)
trend_df_classified_driver = classify_trend_safe(
    trend_df,
    id_col="driver_id",
    pos_threshold=5.0,    # +5% defines "strong positive"
    neg_threshold=-5.0,   # -5% defines "strong negative"
    stable_abs=5.0        # within ±5% considered "stable"
)




trend_df_classified_driver['Total_revenue_of_3year'] = trend_df_classified_driver['rev_2022'] +trend_df_classified_driver['rev_2023']+trend_df_classified_driver['rev_2024']

# 4) inspect result
display(trend_df_classified_driver.head(10))

trend_df_classified_driver.to_csv('../Data/processed/driver_trend_classified.csv', index=False)
print("Output columns:", trend_df_classified_driver.columns.tolist())
# Out:
# __year_val driver_id  rev_2022  rev_2023  rev_2024  yoy_2022_2023  \
# 0           DRV00001 653491.18 665702.48 666489.60           1.87
# 1           DRV00002 673174.83 707543.55 692903.12           5.11
# 2           DRV00003 741799.80 768879.59 636298.08           3.65
# 3           DRV00004 759447.54 663922.07 695991.84         -12.58
# 4           DRV00005 633591.33 594838.85 793927.28          -6.12
# 5           DRV00006 668209.00 614471.63 665530.84          -8.04
# 6           DRV00009 744900.49 699767.62 629130.83          -6.06
# 7           DRV00010 714301.08 743100.59 687257.26           4.03
# 8           DRV00011 728107.44 687418.24 737870.87          -5.59
# 9           DRV00012 639267.41 503044.27 607553.98         -21.31
#
# __year_val  yoy_2023_2024  cagr_2022_2024    trend_label  \
# 0                    0.12            0.99         Stable
# 1                   -2.07            1.45         Upward
# 2                  -17.24           -7.38      Declining
# ...

# %%
driver_monthly_metrics_df.columns.tolist()
# Out:
# ['driver_id',
#  'month',
#  'trips_completed',
#  'total_miles',
#  'total_revenue',
#  'average_mpg',
#  'total_fuel_gallons',
#  'on_time_delivery_rate',
#  'average_idle_hours',
#  'year']

# %% [markdown]
# #### 3.2 Driver On-Time Performance Analysis

# %%
driver_on_time_rate = driver_monthly_metrics_df.groupby(['driver_id']).agg(
    Total_trip =('trips_completed','sum'),
    Avg_on_time_delivery_rate = ('on_time_delivery_rate','mean')
).reset_index()

driver_on_time_rate.head()
# Out:
#   driver_id  Total_trip  Avg_on_time_delivery_rate
# 0  DRV00001         632                       0.45
# 1  DRV00002         662                       0.47
# 2  DRV00003         677                       0.45
# 3  DRV00004         659                       0.43
# 4  DRV00005         643                       0.45

# %%
total = len(driver_on_time_rate)

# %%
driver_on_time_rate['Avg_%driver_on_time_rate'] = driver_on_time_rate['Avg_on_time_delivery_rate']*100
driver_on_time_rate.head()
# Out:
#   driver_id  Total_trip  Avg_on_time_delivery_rate  Avg_%driver_on_time_rate
# 0  DRV00001         632                       0.45                     45.42
# 1  DRV00002         662                       0.47                     46.84
# 2  DRV00003         677                       0.45                     45.08
# 3  DRV00004         659                       0.43                     42.83
# 4  DRV00005         643                       0.45                     45.41

# %%
Top_10_best_driver_leaderboard = leaderboard.sort_values(by='driver_score_100',ascending=False).head(10)
Top_10_worst_driver_leaderboard = leaderboard.sort_values(by='driver_score_100').head(10)
Top_10_best_on_time = driver_on_time_rate.sort_values(by='Avg_%driver_on_time_rate',ascending=False).head(10)
Top_10_worst_on_time = driver_on_time_rate.sort_values(by='Avg_%driver_on_time_rate').head(10)
Top_10_highest_trip =  leaderboard.sort_values(by='Total_trip',ascending=False).head(10)
Top_10_lowest_trip =  leaderboard.sort_values(by='Total_trip').head(10)

# %% [markdown]
# #### 3.4 Driver Performance Visualization

# %%
import matplotlib.pyplot as plt



#Graph 1: Trend Distribution (Count Bar Plot)
trend_counts = trend_df_classified_driver['trend_label'].value_counts()

plt.figure(figsize=(7, 5))
trend_counts.plot(kind='bar')
plt.xlabel("Trend Category")
plt.ylabel("Number of Drivers")
plt.title("Driver Revenue Trend Distribution")
plt.show()

top_drivers = (
    trend_df_classified_driver
    .sort_values('Total_revenue_of_3year', ascending=False)
    .head(10)
)


#2 Total Revenue by Driver (Top Contributors)
top_drivers = (
    trend_df_classified_driver
    .assign(total_rev_million=lambda x: x['Total_revenue_of_3year'] / 1_000_000)
    .sort_values('total_rev_million', ascending=False)
    .head(10)
)

plt.figure(figsize=(10, 5))
plt.bar(
    top_drivers['driver_id'].astype(str),
    top_drivers['total_rev_million']
)
plt.xlabel("Driver ID")
plt.ylabel("Total Revenue (Million)")
plt.title("Top 10 Drivers by Total Revenue (2022–2024)")
plt.xticks(rotation=45)
plt.show()



#Graph 3: Revenue vs Long-Term Growth (ONE-LOOK INSIGHT GRAPH)
plt.figure(figsize=(10, 6))

for trend in trend_df_classified_driver['trend_label'].unique():
    subset = trend_df_classified_driver[
        trend_df_classified_driver['trend_label'] == trend
    ]
    plt.scatter(
        subset['Total_revenue_of_3year'],
        subset['cagr_2022_2024'],
        label=trend,
        alpha=0.7
    )

plt.axhline(0)
plt.xlabel("Total Revenue (2022–2024)")
plt.ylabel("Revenue Growth (CAGR 2022–2024)")
plt.title("Driver Revenue vs Long-Term Growth")
plt.legend(title="Trend Category")
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# BEST revenue per mile
axes[0].bar(
    Top_10_best_revenue_miles.head(10)['driver_id'].astype(str),
    Top_10_best_revenue_miles.head(10)['revenue_per_miles']
)
axes[0].set_title("Top 10 Drivers by Revenue per Mile")
axes[0].set_xlabel("Driver ID")
axes[0].set_ylabel("Revenue per Mile")
axes[0].tick_params(axis='x', rotation=45)

# WORST revenue per mile
axes[1].bar(
    Top_10_worst_revenue_miles.head(10)['driver_id'].astype(str),
    Top_10_worst_revenue_miles.head(10)['revenue_per_miles']
)
axes[1].set_title("Bottom 10 Drivers by Revenue per Mile")
axes[1].set_xlabel("Driver ID")
axes[1].set_ylabel("Revenue per Mile")
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Best and worst performers are visualized side by side using independent bar charts
# to allow direct comparison without scale distortion.

# %%
#1️⃣ Driver Leaderboard (Best vs Worst by Score)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# BEST drivers
axes[0].bar(
    Top_10_best_driver_leaderboard['driver_id'].astype(str),
    Top_10_best_driver_leaderboard['driver_score_100']
)
axes[0].set_title("Top 10 Best Drivers (Performance Score)")
axes[0].set_xlabel("Driver ID")
axes[0].set_ylabel("Driver Score")
axes[0].tick_params(axis='x', rotation=45)

# WORST drivers
axes[1].bar(
    Top_10_worst_driver_leaderboard['driver_id'].astype(str),
    Top_10_worst_driver_leaderboard['driver_score_100']
)
axes[1].set_title("Top 10 Worst Drivers (Performance Score)")
axes[1].set_xlabel("Driver ID")
axes[1].set_ylabel("Driver Score")
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()


#2 .On-Time Performance (Best vs Worst)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# BEST on-time drivers
axes[0].bar(
    Top_10_best_on_time['driver_id'].astype(str),
    Top_10_best_on_time['Avg_%driver_on_time_rate']
)
axes[0].set_title("Top 10 Best On-Time Drivers")
axes[0].set_xlabel("Driver ID")
axes[0].set_ylabel("On-Time Rate (%)")
axes[0].tick_params(axis='x', rotation=45)

# WORST on-time drivers
axes[1].bar(
    Top_10_worst_on_time['driver_id'].astype(str),
    Top_10_worst_on_time['Avg_%driver_on_time_rate']
)
axes[1].set_title("Top 10 Worst On-Time Drivers")
axes[1].set_xlabel("Driver ID")
axes[1].set_ylabel("On-Time Rate (%)")
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

#3Trip Volume (Highest vs Lowest)
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# HIGHEST trips
axes[0].bar(
    Top_10_highest_trip['driver_id'].astype(str),
    Top_10_highest_trip['Total_trip']
)
axes[0].set_title("Top 10 Drivers by Highest Trips")
axes[0].set_xlabel("Driver ID")
axes[0].set_ylabel("Total Trips")
axes[0].tick_params(axis='x', rotation=45)

# LOWEST trips
axes[1].bar(
    Top_10_lowest_trip['driver_id'].astype(str),
    Top_10_lowest_trip['Total_trip']
)
axes[1].set_title("Top 10 Drivers by Lowest Trips")
axes[1].set_xlabel("Driver ID")
axes[1].set_ylabel("Total Trips")
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Route Profitability Analysis

# %% [markdown]
# #### 4.1 Route-Level Revenue Aggregation

# %%
route_df.head()
# Out:
#    route_id origin_city origin_state destination_city destination_state  \
# 0  RTE00001     Atlanta           GA          Chicago                IL
# 1  RTE00002     Atlanta           GA            Miami                FL
# 2  RTE00003     Chicago           IL      Los Angeles                CA
# 3  RTE00004     Chicago           IL         Portland                OR
# 4  RTE00005     Chicago           IL        Las Vegas                NV
#
#    typical_distance_miles  base_rate_per_mile  fuel_surcharge_rate  \
# 0                     677                1.70                 0.19
# 1                     697                2.08                 0.22
# 2                    2003                2.55                 0.29
# 3                    2017                1.84                 0.19
# 4                    1749                2.41                 0.26
#
#    typical_transit_days
# 0                     1
# 1                     1
# 2                     3
# 3                     3
# ...

# %%
loads_df.head()
# Out:
#         load_id customer_id  route_id   load_date     load_type  weight_lbs  \
# 0  LOAD00000001   CUST00183  RTE00019  2022-01-01       Dry Van       19178
# 1  LOAD00000002   CUST00076  RTE00058  2022-01-01       Dry Van       27761
# 2  LOAD00000003   CUST00027  RTE00048  2022-01-01  Refrigerated       35594
# 3  LOAD00000004   CUST00088  RTE00013  2022-01-01  Refrigerated       33274
# 4  LOAD00000005   CUST00185  RTE00020  2022-01-01       Dry Van       40257
#
#    pieces  revenue  fuel_surcharge  accessorial_charges load_status  \
# 0      13  3045.23          406.72                  100   Completed
# 1      22  1224.48           98.61                    0   Completed
# 2      16  7171.12          792.88                    0   Completed
# 3      10  1308.20          141.33                   50   Completed
# 4      10  3317.18          738.48                    0   Completed
#
#   booking_type
# 0         Spot
# 1    Dedicated
# 2         Spot
# 3         Spot
# 4         Spot

# %%
loads_df['load_date'] = pd.to_datetime(loads_df['load_date'],errors='coerce')
loads_df['year'] =  loads_df['load_date'].dt.year

# %%
routes_groupby =  loads_df.groupby(['route_id','year']).agg(
    sum_total_revenue = ('revenue','sum'),
    sum_fuel_subcharge = ('fuel_surcharge','sum'),
    sum_acessorial_charges =('accessorial_charges','sum')
).reset_index()
routes_groupby.head()
# Out:
#    route_id  year  sum_total_revenue  sum_fuel_subcharge  \
# 0  RTE00001  2022          546331.05            61227.88
# 1  RTE00001  2023          548268.33            61356.51
# 2  RTE00001  2024          580763.42            64700.89
# 3  RTE00002  2022          703358.10            74369.90
# 4  RTE00002  2023          678875.24            71456.44
#
#    sum_acessorial_charges
# 0                   32450
# 1                   35475
# 2                   38750
# 3                   35675
# 4                   29875

# %%
routes_performance = routes_groupby.merge(route_df,on='route_id',how='left')
routes_performance.head()
# Out:
#    route_id  year  sum_total_revenue  sum_fuel_subcharge  \
# 0  RTE00001  2022          546331.05            61227.88
# 1  RTE00001  2023          548268.33            61356.51
# 2  RTE00001  2024          580763.42            64700.89
# 3  RTE00002  2022          703358.10            74369.90
# 4  RTE00002  2023          678875.24            71456.44
#
#    sum_acessorial_charges origin_city origin_state destination_city  \
# 0                   32450     Atlanta           GA          Chicago
# 1                   35475     Atlanta           GA          Chicago
# 2                   38750     Atlanta           GA          Chicago
# 3                   35675     Atlanta           GA            Miami
# 4                   29875     Atlanta           GA            Miami
#
#   destination_state  typical_distance_miles  base_rate_per_mile  \
# 0                IL                     677                1.70
# 1                IL                     677                1.70
# ...

# %% [markdown]
# #### 4.2 Normalized Revenue Metrics
# #### 4.3 Pricing Benchmark & Variance Analysis

# %%
#1 total revenue calculation
routes_performance['Total_revenue'] = routes_performance['sum_total_revenue'] +routes_performance['sum_fuel_subcharge']+routes_performance['sum_acessorial_charges']

#2 Revenue Normalization
routes_performance['revenue_per_mile'] = routes_performance['Total_revenue']/routes_performance['typical_distance_miles']
routes_performance['revenue_per_day'] = routes_performance['Total_revenue']/routes_performance['typical_transit_days']

#3 Expected Revenue
routes_performance['expected_revenue'] = routes_performance['typical_distance_miles']*routes_performance['base_rate_per_mile']

#4 price_variance
routes_performance['price_variance'] = routes_performance['Total_revenue'] - routes_performance['expected_revenue']
#5 Fuel Surcharge Dependency (Risk Indicator)
routes_performance['fuel_surcharge_pct'] = routes_performance['sum_fuel_subcharge']/routes_performance['Total_revenue']
routes_performance.head()
# Out:
#    route_id  year  sum_total_revenue  sum_fuel_subcharge  \
# 0  RTE00001  2022          546331.05            61227.88
# 1  RTE00001  2023          548268.33            61356.51
# 2  RTE00001  2024          580763.42            64700.89
# 3  RTE00002  2022          703358.10            74369.90
# 4  RTE00002  2023          678875.24            71456.44
#
#    sum_acessorial_charges origin_city origin_state destination_city  \
# 0                   32450     Atlanta           GA          Chicago
# 1                   35475     Atlanta           GA          Chicago
# 2                   38750     Atlanta           GA          Chicago
# 3                   35675     Atlanta           GA            Miami
# 4                   29875     Atlanta           GA            Miami
#
#   destination_state  typical_distance_miles  base_rate_per_mile  \
# 0                IL                     677                1.70
# 1                IL                     677                1.70
# ...

# %%
trips_df_copy =trips_df.copy()
trips_df_copy['dispatch_date'] = pd.to_datetime(trips_df_copy['dispatch_date'],errors='coerce')
trips_df_copy['year'] = trips_df_copy['dispatch_date'].dt.year

routes_fuel = trips_df_copy.groupby(['truck_id','year']).agg(
    sum_actual_distance_miles=('actual_distance_miles','sum'),
    sum_fuel_gallons_used= ('fuel_gallons_used','sum')
    ).reset_index()

routes_fuel.head()
# Out:
#    truck_id  year  sum_actual_distance_miles  sum_fuel_gallons_used
# 0  TRK00001  2022                     481239               75424.00
# 1  TRK00001  2023                     441450               68962.10
# 2  TRK00001  2024                     433708               66376.10
# 3  TRK00002  2022                     427355               66287.50
# 4  TRK00002  2023                     412352               64439.70

# %% [markdown]
# #### 4.4 Estimated Route Cost & Profitability

# %%
routes_cost = routes_performance.copy()

#Fuel Cost Estimation
routes_cost['Fleet_avg_mpg'] = routes_fuel['sum_actual_distance_miles']/routes_fuel['sum_fuel_gallons_used']
routes_cost['Estimated_fuel_gallon'] = routes_cost['typical_distance_miles']/routes_cost['Fleet_avg_mpg']
routes_cost['Estimated_fuel_cost'] = routes_cost['Estimated_fuel_gallon'] * 3.81 #average Fuel is 3.81
routes_cost['Fuel_cost_per_miles'] = routes_cost['Estimated_fuel_cost']/routes_cost['typical_distance_miles']
routes_cost['Fuel_recovery_ratio'] =  routes_cost['sum_fuel_subcharge']/routes_cost['Estimated_fuel_cost']

#Profitability
routes_cost['profit_per_miles'] = routes_cost['revenue_per_mile'] - routes_cost['Fuel_cost_per_miles']
routes_cost['Profit_per_day'] = routes_cost['revenue_per_day'] -(routes_cost['Estimated_fuel_cost']/routes_cost['typical_transit_days'])


routes_cost['fleet_avg_revenue_per_mile'] = routes_cost['Total_revenue']/routes_cost['typical_distance_miles']
#Route Health Flags
routes_cost['Fuel_loss_flag'] = routes_cost['Fuel_recovery_ratio'] <1
routes_cost['underprices_flag'] = routes_cost['price_variance'] < 0
routes_cost['High_surcharge_flag'] = routes_cost['fuel_surcharge_pct']  >0.3
routes_cost['Low_density_flag'] = routes_cost['revenue_per_mile']  < routes_cost['fleet_avg_revenue_per_mile']


routes_cost.head()
# Out:
#    route_id  year  sum_total_revenue  sum_fuel_subcharge  \
# 0  RTE00001  2022          546331.05            61227.88
# 1  RTE00001  2023          548268.33            61356.51
# 2  RTE00001  2024          580763.42            64700.89
# 3  RTE00002  2022          703358.10            74369.90
# 4  RTE00002  2023          678875.24            71456.44
#
#    sum_acessorial_charges origin_city origin_state destination_city  \
# 0                   32450     Atlanta           GA          Chicago
# 1                   35475     Atlanta           GA          Chicago
# 2                   38750     Atlanta           GA          Chicago
# 3                   35675     Atlanta           GA            Miami
# 4                   29875     Atlanta           GA            Miami
#
#   destination_state  typical_distance_miles  ...  Estimated_fuel_cost  \
# 0                IL                     677  ...               404.26
# ...

# %%
routes_cost.columns.to_list()
# Out:
# ['route_id',
#  'year',
#  'sum_total_revenue',
#  'sum_fuel_subcharge',
#  'sum_acessorial_charges',
#  'origin_city',
#  'origin_state',
#  'destination_city',
#  'destination_state',
#  'typical_distance_miles',
#  'base_rate_per_mile',
#  'fuel_surcharge_rate',
#  'typical_transit_days',
#  'Total_revenue',
#  'revenue_per_mile',
#  'revenue_per_day',
#  'expected_revenue',
#  'price_variance',
#  'fuel_surcharge_pct',
#  'Fleet_avg_mpg',
#  'Estimated_fuel_gallon',
#  'Estimated_fuel_cost',
#  'Fuel_cost_per_miles',
#  'Fuel_recovery_ratio',
#  'profit_per_miles',
#  'Profit_per_day',
#  'fleet_avg_revenue_per_mile',
#  'Fuel_loss_flag',
#  'underprices_flag',
#  'High_surcharge_flag',
#  'Low_density_flag']

# %%
def classify_route_health(row):

    # Weak routes
    if (row['profit_per_miles'] < 0) or (row['underprices_flag'] == True):
        return 'Weak'

    # At Risk routes
    elif (
        (row['Fuel_loss_flag'] == True) or
        (row['High_surcharge_flag'] == True) or
        (row['Low_density_flag'] == True)
    ):
        return 'At Risk'

    # Strong routes
    else:
        return 'Strong'

# %%
routes_cost['route_health'] = routes_cost.apply(
    classify_route_health,
    axis=1
)
routes_cost['route_health'].value_counts()
# Out:
# route_health
# Strong    174
# Name: count, dtype: int64

# %%
routes_cost_copy = routes_cost.copy()
# 2) call the robust pivot + YoY function
# Note: value_col is your revenue column name: 'sum_total_revenue'
trend_df = calc_yoy_growth_dynamic_safe(
    routes_cost_copy,
    id_col="route_id",
    year_col="year",
    value_col="Total_revenue"
)

# 3) classify trends with default thresholds (change thresholds if needed)
trend_df_classified_routes = classify_trend_safe(
    trend_df,
    id_col="route_id",
    pos_threshold=5.0,    # +5% defines "strong positive"
    neg_threshold=-5.0,   # -5% defines "strong negative"
    stable_abs=5.0        # within ±5% considered "stable"
)
# 4) inspect result
display(trend_df_classified_routes.head(10))

trend_df_classified_routes.to_csv('../Data/processed/trend_df_classified_routes.csv', index=False)
print("Output columns:", trend_df_classified_routes.columns.tolist())
# Out:
# __year_val  route_id   rev_2022   rev_2023   rev_2024  yoy_2022_2023  \
# 0           RTE00001  640008.93  645099.84  684214.31           0.80
# 1           RTE00002  813403.00  780206.68  891652.98          -4.08
# 2           RTE00003 2950123.14 2743837.51 2905726.67          -6.99
# 3           RTE00004 2138009.00 1961951.69 1983007.28          -8.23
# 4           RTE00005 2369992.39 2274691.37 2368121.38          -4.02
# 5           RTE00006  867009.82  793471.74  821822.43          -8.48
# 6           RTE00007 2339893.71 2308065.23 2225863.00          -1.36
# 7           RTE00008 1123955.01 1032218.81 1028068.34          -8.16
# 8           RTE00009  959223.95  895093.75  996191.36          -6.69
# 9           RTE00010  118989.30  110296.09  119447.18          -7.31
#
# __year_val  yoy_2023_2024  cagr_2022_2024    trend_label
# 0                    6.06            3.40  Strong Upward
# 1                   14.28            4.70  Strong Upward
# ...

# %%
routes_profit_per_miles =  routes_cost.groupby(['route_id']).agg(
    Total_profit_per_miles =('profit_per_miles','sum'),
    Total_Fuel_recovery_ratio = ('Fuel_recovery_ratio','sum'),
    Total_price_variance = ('price_variance','sum')
).reset_index()
Top_10_best_routes_profit_per_miles = routes_profit_per_miles.sort_values(by='Total_profit_per_miles',ascending=False).head(10)
Top_10_Worst_routes_profit_per_miles = routes_profit_per_miles.sort_values(by='Total_profit_per_miles').head(10)
Top_10_best_routes_Fuel_recovery_ratio = routes_profit_per_miles.sort_values(by='Total_Fuel_recovery_ratio',ascending=False).head(10)
Top_10_wost_routes_Fuel_recovery_ratio = routes_profit_per_miles.sort_values(by='Total_Fuel_recovery_ratio').head(10)

Top_10_best_routes_price_variance = routes_profit_per_miles.sort_values(by='Total_price_variance',ascending=False).head(10)
Top_10_worst_routes_price_variance = routes_profit_per_miles.sort_values(by='Total_price_variance').head(10)

# %% [markdown]
# #### 4.6 Final Route Profitability Tables

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

fig, axes = plt.subplots(1, 2, figsize=(18, 6))
fig.suptitle("Route Profitability per Mile — Best vs Worst Routes", fontsize=16)

# -----------------------------
# 🔹 Top 10 BEST Routes
# -----------------------------
sns.barplot(
    data=Top_10_best_routes_profit_per_miles,
    x='Total_profit_per_miles',
    y='route_id',
    palette='dark:green',
    hue='Total_profit_per_miles',
    legend=False,
    ax=axes[0]
)

axes[0].set_title("Top 10 Routes by Profit per Mile")
axes[0].set_xlabel("Profit per Mile")
axes[0].set_ylabel("Route ID")

# -----------------------------
# 🔹 Top 10 WORST Routes
# -----------------------------
sns.barplot(
    data=Top_10_Worst_routes_profit_per_miles,
    x='Total_profit_per_miles',
    y='route_id',
    palette='dark:red',
    hue = 'Total_profit_per_miles',
    legend=False,
    ax=axes[1]
)

axes[1].set_title("Bottom 10 Routes by Profit per Mile")
axes[1].set_xlabel("Profit per Mile")
axes[1].set_ylabel("Route ID")

plt.tight_layout(rect=[0, 0, 1, 0.94])
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,6))
fig.suptitle("Fuel Recovery Ratio — Best vs Worst Routes", fontsize=14)

# Top routes
sns.barplot(
    data=Top_10_best_routes_Fuel_recovery_ratio,
    x='Total_Fuel_recovery_ratio',
    y='route_id',
    palette='dark:green',
    hue ='Total_Fuel_recovery_ratio',
    legend=False,
    ax=axes[0]
)

axes[0].set_title("Top Routes — Fuel Recovery")
axes[0].set_xlabel("Fuel Recovery Ratio")
axes[0].set_ylabel("Route ID")

# Bottom routes
sns.barplot(
    data=Top_10_wost_routes_Fuel_recovery_ratio,
    x='Total_Fuel_recovery_ratio',
    y='route_id',
    palette='dark:red',
    hue ='Total_Fuel_recovery_ratio',
    legend=False,
    ax=axes[1]
)

axes[1].set_title("Worst Routes — Fuel Recovery")
axes[1].set_xlabel("Fuel Recovery Ratio")
axes[1].set_ylabel("Route ID")

plt.tight_layout(rect=[0, 0, 1, 0.93])
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,6))
fig.suptitle("Price Variance — Best vs Worst Routes", fontsize=14)

# Top routes
sns.barplot(
    data=Top_10_best_routes_price_variance,
    x='Total_price_variance',
    y='route_id',
    palette='dark:blue',
    hue='Total_price_variance',
    legend=False,
    ax=axes[0]
)

axes[0].set_title("Top Routes — Price Variance")
axes[0].set_xlabel("Price Variance")
axes[0].set_ylabel("Route ID")

# Worst routes
sns.barplot(
    data=Top_10_best_routes_price_variance,
    x='Total_price_variance',
    y='route_id',
    palette='dark:red',
    hue='Total_price_variance',
    legend=False,
    ax=axes[1]
)

axes[1].set_title("Worst Routes — Price Variance")
axes[1].set_xlabel("Price Variance")
axes[1].set_ylabel("Route ID")

plt.tight_layout(rect=[0, 0, 1, 0.93])
plt.show()

# %%
plt.figure(figsize=(6,5))

sns.countplot(
    data=routes_cost,
    x='route_health',
    order=['Strong', 'At Risk', 'Weak'],
    palette=['green', 'orange', 'red'],
    hue='route_health',
    legend=False
)

plt.title("Route Health Distribution")
plt.xlabel("Route Health")
plt.ylabel("Number of Routes")
plt.show()
# Out:
# C:\Users\amanc\AppData\Local\Temp\ipykernel_14100\2555793952.py:3: UserWarning: The palette list has more values (3) than needed (1), which may not be intended.
#   sns.countplot(

# %%
trucks_df.head()
# Out:
#    truck_id  unit_number          make  model_year                 vin  \
# 0  TRK00001         3463     Peterbilt        2016  1VV205190335317039
# 1  TRK00002         6461      Kenworth        2015  1NV753749606229960
# 2  TRK00003         2335     Peterbilt        2018  1NT803101860493229
# 3  TRK00004         3317  Freightliner        2015  1VV131945381692351
# 4  TRK00005         6731  Freightliner        2016  1FT822215709701985
#
#   acquisition_date  acquisition_mileage fuel_type  tank_capacity_gallons  \
# 0       2017-04-27                18814    Diesel                    200
# 1       2018-10-04                26795    Diesel                    150
# 2       2020-09-17                11795    Diesel                    150
# 3       2017-06-17                 8875    Diesel                    200
# 4       2021-10-08                42042    Diesel                    250
#
#         status   home_terminal
# 0       Active           Omaha
# 1       Active         Seattle
# ...

# %%
truck_utilization_metrics_df.head()
# Out:
#    truck_id       month  trips_completed  total_miles  total_revenue  \
# 0  TRK00001  2022-01-01               22        39269       84792.02
# 1  TRK00001  2022-02-01               27        40787       88809.05
# 2  TRK00001  2022-03-01               34        57422      120453.71
# 3  TRK00001  2022-04-01               20        34428       73531.28
# 4  TRK00001  2022-05-01               16        20851       40791.53
#
#    average_mpg  maintenance_events  maintenance_cost  downtime_hours  \
# 0         6.78                   2           4380.98           63.10
# 1         6.23                   0              0.00            0.00
# 2         6.49                   0              0.00            0.00
# 3         6.50                   2           3548.15           71.80
# 4         6.38                   1           1969.42           43.90
#
#    utilization_rate
# 0              0.71
# 1              0.96
# 2              1.10
# 3              0.67
# 4              0.52

# %%
truck_utilization_metrics_df_copy = truck_utilization_metrics_df.copy()
truck_utilization_metrics_df_copy['month'] = pd.to_datetime(truck_utilization_metrics_df_copy['month'],errors='coerce')
truck_utilization_metrics_df_copy['year'] = truck_utilization_metrics_df_copy['month'].dt.year

truck_groupby = truck_utilization_metrics_df_copy.groupby(['truck_id','year']).agg(
    sum_Total_trips =('trips_completed','sum'),
    sum_total_miles =('total_miles','sum'),
    sum_total_revenue = ('total_revenue','sum'),
    sum_maintenance_cost = ('maintenance_cost','sum'),
    Avg_downtime_hours = ('downtime_hours','mean'),
    Avg_utilization_rate = ('utilization_rate','mean')
).reset_index()

truck_groupby.head()
# Out:
#    truck_id  year  sum_Total_trips  sum_total_miles  sum_total_revenue  \
# 0  TRK00001  2022              319           481239         1024755.98
# 1  TRK00001  2023              315           441450          941116.80
# 2  TRK00001  2024              317           433708          930465.39
# 3  TRK00002  2022              304           427355          915640.07
# 4  TRK00002  2023              292           412352          879009.31
#
#    sum_maintenance_cost  Avg_downtime_hours  Avg_utilization_rate
# 0              17501.20               27.47                  0.87
# 1              21003.65               23.66                  0.86
# 2              13271.14                8.31                  0.86
# 3              17188.16               14.02                  0.83
# 4              21633.92               30.33                  0.80

# %%
truck_performance = truck_groupby.merge(trucks_df['truck_id'],on='truck_id',how='left')
truck_performance.head()
# Out:
#    truck_id  year  sum_Total_trips  sum_total_miles  sum_total_revenue  \
# 0  TRK00001  2022              319           481239         1024755.98
# 1  TRK00001  2023              315           441450          941116.80
# 2  TRK00001  2024              317           433708          930465.39
# 3  TRK00002  2022              304           427355          915640.07
# 4  TRK00002  2023              292           412352          879009.31
#
#    sum_maintenance_cost  Avg_downtime_hours  Avg_utilization_rate
# 0              17501.20               27.47                  0.87
# 1              21003.65               23.66                  0.86
# 2              13271.14                8.31                  0.86
# 3              17188.16               14.02                  0.83
# 4              21633.92               30.33                  0.80

# %%
trips_df_truck_copy = trips_df.copy()
trips_df_truck_copy['dispatch_date'] = pd.to_datetime(trips_df_truck_copy['dispatch_date'],errors='coerce')
trips_df_truck_copy['year'] =  trips_df_truck_copy['dispatch_date'].dt.year
trips_df_truck_copy.head()
# Out:
#         trip_id       load_id driver_id  truck_id trailer_id dispatch_date  \
# 0  TRIP00000001  LOAD00000001  DRV00117  TRK00035   TRL00167    2022-01-01
# 1  TRIP00000002  LOAD00000002  DRV00141  TRK00108   TRL00082    2022-01-01
# 2  TRIP00000003  LOAD00000003  DRV00032  TRK00031   TRL00138    2022-01-01
# 3  TRIP00000004  LOAD00000004  DRV00083  TRK00105   TRL00018    2022-01-01
# 4  TRIP00000005  LOAD00000005  DRV00044  TRK00076   TRL00054    2022-01-01
#
#    actual_distance_miles  actual_duration_hours  fuel_gallons_used  \
# 0                   1314                  26.20             183.80
# 1                    515                   8.60              93.60
# 2                   2509                  45.00             339.10
# 3                    717                  11.10             110.30
# 4                   2243                  35.00             328.90
#
#    average_mpg  idle_time_hours trip_status  year
# 0         7.15             3.50   Completed  2022
# ...

# %%
truck_fuel_gallons = trips_df_truck_copy.groupby(['truck_id','year']).agg(
    sum_actual_duration_hours = ('actual_duration_hours','sum'),
    sum_fuel_gallons_used = ('fuel_gallons_used','sum')
).reset_index()
truck_fuel_gallons.head()
# Out:
#    truck_id  year  sum_actual_duration_hours  sum_fuel_gallons_used
# 0  TRK00001  2022                    8435.40               75424.00
# 1  TRK00001  2023                    7741.60               68962.10
# 2  TRK00001  2024                    7617.20               66376.10
# 3  TRK00002  2022                    7513.60               66287.50
# 4  TRK00002  2023                    7229.00               64439.70

# %%
truck_performance_tab = truck_performance.merge(truck_fuel_gallons,on=['truck_id','year'],how='left')
truck_performance_tab.head()
# Out:
#    truck_id  year  sum_Total_trips  sum_total_miles  sum_total_revenue  \
# 0  TRK00001  2022              319           481239         1024755.98
# 1  TRK00001  2023              315           441450          941116.80
# 2  TRK00001  2024              317           433708          930465.39
# 3  TRK00002  2022              304           427355          915640.07
# 4  TRK00002  2023              292           412352          879009.31
#
#    sum_maintenance_cost  Avg_downtime_hours  Avg_utilization_rate  \
# 0              17501.20               27.47                  0.87
# 1              21003.65               23.66                  0.86
# 2              13271.14                8.31                  0.86
# 3              17188.16               14.02                  0.83
# 4              21633.92               30.33                  0.80
#
#    sum_actual_duration_hours  sum_fuel_gallons_used
# 0                    8435.40               75424.00
# ...

# %%
truck_performance_tab.columns.to_list()
# Out:
# ['truck_id',
#  'year',
#  'sum_Total_trips',
#  'sum_total_miles',
#  'sum_total_revenue',
#  'sum_maintenance_cost',
#  'Avg_downtime_hours',
#  'Avg_utilization_rate',
#  'sum_actual_duration_hours',
#  'sum_fuel_gallons_used']

# %%
#A) miles per trip
truck_performance_tab['miles_per_trip'] = truck_performance_tab['sum_total_miles']/truck_performance_tab['sum_Total_trips']
#B) MPG (Fleet Fuel Efficiency)
truck_performance_tab['MPG'] = truck_performance_tab['sum_total_miles']/truck_performance_tab['sum_fuel_gallons_used']
#C) Fuel cost per mile
truck_performance_tab['fuel_cost'] = truck_performance_tab['sum_fuel_gallons_used'] * avg_fuel_price
truck_performance_tab['fuel_cost_per_miles'] = truck_performance_tab['fuel_cost']/truck_performance_tab['sum_fuel_gallons_used']
#D) Hours per trip
truck_performance_tab['hours_per_trips'] = truck_performance_tab['sum_total_miles']/truck_performance_tab['sum_Total_trips']
#E) Revenue per mile
truck_performance_tab['revenue_per_miles'] = truck_performance_tab['sum_total_revenue']/truck_performance_tab['sum_total_miles']
#2. Fleet Profitability Metrics
#A) Maintenance cost per mile
truck_performance_tab['Maintenance_per_miles'] = truck_performance_tab['sum_maintenance_cost']/truck_performance_tab['sum_total_miles']
#B) Operating cost = Fuel cost + maintenance cost
truck_performance_tab['operating_cost'] = truck_performance_tab['fuel_cost'] + truck_performance_tab['sum_maintenance_cost']
#C) Operating cost per mile
truck_performance_tab['operating_cost_per_miles'] = truck_performance_tab['operating_cost']/truck_performance_tab['sum_total_miles']
#D) Profit per mile
truck_performance_tab['profit_per_mile'] = truck_performance_tab['revenue_per_miles'] - truck_performance_tab['operating_cost_per_miles']
#E) Total profit per truck
truck_performance_tab['total_profit'] = truck_performance_tab['sum_total_revenue'] - truck_performance_tab['operating_cost']
#3. Fleet Reliability Metrics
truck_performance_tab['down_time_rate'] = truck_performance_tab['Avg_downtime_hours']/truck_performance_tab['sum_total_miles']
#B) Availability%
truck_performance_tab['availability_pct'] = (
    1 - (truck_performance_tab['Avg_downtime_hours'] / 720)
) * 100
# C) Trips per downtime hour
truck_performance_tab['trips_per_downtime_hr'] = (
    truck_performance_tab['sum_Total_trips'] / truck_performance_tab['Avg_downtime_hours']
)

truck_performance_tab.head()
# Out:
#    truck_id  year  sum_Total_trips  sum_total_miles  sum_total_revenue  \
# 0  TRK00001  2022              319           481239         1024755.98
# 1  TRK00001  2023              315           441450          941116.80
# 2  TRK00001  2024              317           433708          930465.39
# 3  TRK00002  2022              304           427355          915640.07
# 4  TRK00002  2023              292           412352          879009.31
#
#    sum_maintenance_cost  Avg_downtime_hours  Avg_utilization_rate  \
# 0              17501.20               27.47                  0.87
# 1              21003.65               23.66                  0.86
# 2              13271.14                8.31                  0.86
# 3              17188.16               14.02                  0.83
# 4              21633.92               30.33                  0.80
#
#    sum_actual_duration_hours  sum_fuel_gallons_used  ...  hours_per_trips  \
# ...

# %%
truck_performance_tab_copy = truck_performance_tab.copy()
# 2) call the robust pivot + YoY function
# Note: value_col is your revenue column name: 'sum_total_revenue'
trend_df = calc_yoy_growth_dynamic_safe(
    truck_performance_tab_copy,
    id_col="truck_id",
    year_col="year",
    value_col="sum_total_revenue"
)

# 3) classify trends with default thresholds (change thresholds if needed)
trend_df_classified_truck = classify_trend_safe(
    trend_df,
    id_col="truck_id",
    pos_threshold=5.0,    # +5% defines "strong positive"
    neg_threshold=-5.0,   # -5% defines "strong negative"
    stable_abs=5.0        # within ±5% considered "stable"
)
# 4) inspect result
display(trend_df_classified_truck.head(10))

trend_df_classified_truck.to_csv('../Data/processed/trend_df_classified_truck.csv', index=False)
print("Output columns:", trend_df_classified_truck.columns.tolist())
# Out:
# __year_val  truck_id   rev_2022   rev_2023   rev_2024  yoy_2022_2023  \
# 0           TRK00001 1024755.98  941116.80  930465.39          -8.16
# 1           TRK00002  915640.07  879009.31  917712.48          -4.00
# 2           TRK00004 1019800.20  920188.32  863613.61          -9.77
# 3           TRK00006  848000.97  972121.57  958424.01          14.64
# 4           TRK00007  948952.29 1009339.78  929456.10           6.36
# 5           TRK00008  887906.51  984483.62  908198.89          10.88
# 6           TRK00009  931124.33  883307.33 1018493.17          -5.14
# 7           TRK00010  890243.60  853807.84 1033896.71          -4.09
# 8           TRK00011  974920.80  915519.75  923603.57          -6.09
# 9           TRK00012  948139.00  961713.04  974313.78           1.43
#
# __year_val  yoy_2023_2024  cagr_2022_2024    trend_label
# 0                   -1.13           -4.71       Volatile
# 1                    4.40            0.11         Stable
# ...

# %%
# ================= 4️⃣ FLEET SCORECARD (RANKING) ==================

from sklearn.preprocessing import MinMaxScaler

score_df = truck_performance_tab_copy.copy()

# Metrics where higher = better
pos_cols = ['MPG','revenue_per_miles','profit_per_mile','availability_pct']

# Metrics where lower = better (invert them)
neg_cols = ['fuel_cost_per_miles','Maintenance_per_miles','down_time_rate']

scaler = MinMaxScaler()

# Normalize positive metrics
score_df[pos_cols] = scaler.fit_transform(score_df[pos_cols])

# Normalize negative metrics (invert)
score_df[neg_cols] = 1 - scaler.fit_transform(score_df[neg_cols])

# Final weighted score
score_df['fleet_score'] = (
    score_df['MPG']*0.20 +
    score_df['revenue_per_miles']*0.20 +
    score_df['profit_per_mile']*0.25 +
    score_df['availability_pct']*0.15 +
    score_df['fuel_cost_per_miles']*0.10 +
    score_df['Maintenance_per_miles']*0.10
)
# Out:
#    truck_id  year  sum_Total_trips  sum_total_miles  sum_total_revenue  \
# 0  TRK00001  2022              319           481239         1024755.98
# 1  TRK00001  2023              315           441450          941116.80
# 2  TRK00001  2024              317           433708          930465.39
# 3  TRK00002  2022              304           427355          915640.07
# 4  TRK00002  2023              292           412352          879009.31
#
#    sum_maintenance_cost  Avg_downtime_hours  Avg_utilization_rate  \
# 0              17501.20               27.47                  0.87
# 1              21003.65               23.66                  0.86
# 2              13271.14                8.31                  0.86
# 3              17188.16               14.02                  0.83
# 4              21633.92               30.33                  0.80
#
#    sum_actual_duration_hours  sum_fuel_gallons_used  ...  revenue_per_miles  \
# ...

# %%
top10_fleet = score_df.nlargest(10, 'fleet_score')

plt.figure(figsize=(10,5))
sns.barplot(data=top10_fleet.sort_values('fleet_score'),
            x='fleet_score', y='truck_id', palette='viridis',hue='fleet_score',legend= False)
plt.title("Fleet Performance Score — Top 10 Trucks")
plt.xlabel("Fleet Score")
plt.ylabel("Truck ID")
plt.show()
